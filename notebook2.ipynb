# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parents[0]  # adjust if notebook is nested deeper
sys.path.append(str(PROJECT_ROOT))

# %%
from src.shared.database.client import SQLModelClient
import json
import pandas as pd
from datetime import datetime, UTC

# %%
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import plotly.io as pio

# Set ploting default
pio.templates.default = "plotly_dark"
px.defaults.height = 600
px.defaults.template = "plotly_dark"
px.defaults.color_continuous_scale = px.colors.sequential.Bluyl_r
px.defaults.color_discrete_sequence = px.colors.sequential.Bluyl_r


plotly_config = {
  "staticPlot": True,
#   "scrollZoom": True,
  "displayModeBar": False,
  "editable": True,
}


# np.random.seed (21)
pd.set_option ("display.max_rows", 20)
pd.set_option ("display.max_columns", 15)
pd.options.plotting.backend = "plotly"

# mute warnings
# warnings.filterwarnings ("ignore")

# %%
database_client = SQLModelClient(database_url="postgresql://dev_user_1:dev_user_1_password@localhost:5432/investment_db")

with database_client as db:
  res = db.execute(
    f"""
    SELECT *
    FROM staging.asset_v2 t1
    inner join staging.asset_computed t2
      ON t1.id = t2.asset_id
  """
  )
  res = res.fetchall()
df = pd.DataFrame(res)
df.columns
# Out:
# Index(['id', 'data_timestamp', 'external_id', 'ticker', 'name', 'description',
#        'broker', 'currency', 'local_currency', 'share', 'price', 'avg_price',
#        'value', 'cost', 'profit', 'fx_impact', 'business_key',
#        'created_timestamp', 'updated_timestamp', 'asset_id', 'cashflow',
#        'daily_return', 'cumulative_return', 'dca_bias', 'pct_drawdown',
#        'recent_high_30d', 'recent_low_30d', 'high', 'low', 'ma_20d', 'ma_30d',
#        'ma_50d', 'volatility_20d', 'volatility_30d', 'volatility_50d',
#        'created_timestamp'],
#       dtype='str')

# %%
df.head(3)
# Out:
#                                      id                   data_timestamp  \
# 0  bf26b387-671a-4f0c-86fa-38c99533b93e 2026-02-08 23:51:19.558939+00:00
# 1  59876983-0f31-4d4a-92c6-2564ddb6c627 2026-02-08 23:51:19.591419+00:00
# 2  560ddbea-2b09-42a5-90ab-0fa1fc3176a2 2026-02-08 23:51:19.616227+00:00
#
#   external_id ticker                           name  \
# 0     AMDd_EQ   AMDd         Advanced Micro Devices
# 1    CBUKd_EQ  CBUKd  iShares MSCI China Tech (Acc)
# 2     CHVd_EQ   CHVd                        Chevron
#
#                      description       broker  ...  ma_20d  ma_30d  ma_50d  \
# 0         Advanced Micro Devices  Trading 212  ...   12.62   12.62   12.62
# 1  iShares MSCI China Tech (Acc)  Trading 212  ...  143.88  143.88  143.88
# 2                        Chevron  Trading 212  ...   27.00   27.00   27.00
#
#    volatility_20d  volatility_30d  volatility_50d  \
# 0             NaN             NaN             NaN
# 1             NaN             NaN             NaN
# 2             NaN             NaN             NaN
#
#                  created_timestamp
# 0 2026-02-13 00:54:58.158362+00:00
# 1 2026-02-13 00:54:58.603451+00:00
# 2 2026-02-13 00:54:58.853805+00:00
#
# [3 rows x 36 columns]

# %%
asset_name = 'AMDd'

# %%
total_asset = df.loc[:,['name']].value_counts()
total_asset
# Out:
# name
# Advanced Micro Devices                                160
# iShares MSCI China Tech (Acc)                         147
# Chevron                                               147
# iShares MSCI AC Far East ex-Japan Small Cap (Dist)    147
# Rigetti Computing                                     147
#                                                      ...
# WisdomTree Cloud Computing (Acc)                      147
# Vanguard Global Aggregate Bond (Acc)                  147
# HSBC MSCI CHINA (Acc)                                 147
# iShares MSCI Europe Mid Cap (Dist)                    147
# Nike                                                  147
# Name: count, Length: 59, dtype: int64

# %%
x = df[df['ticker'] == asset_name][['data_timestamp', 'profit', 'ticker']].sort_values(by="data_timestamp")

fig = px.line (
  x,
  "data_timestamp",
  "profit",
#   color_discrete_sequence="Tealgrn_r",
)

fig.update_layout (
  height=500,
)

# %%
x = df[df['ticker'] == asset_name][['data_timestamp', 'price', 'ticker']].sort_values(by="data_timestamp")

fig = px.line (
  x,
  "data_timestamp",
  "price",
#   color_discrete_sequence="Tealgrn_r",
)

fig.update_layout (
  height=500,
)

# %%
x = df[df['ticker'] == asset_name][['data_timestamp', 'daily_return', 'ticker']].sort_values(by="data_timestamp")

fig = px.line (
  x,
  "data_timestamp",
  "daily_return",
#   color_discrete_sequence="Tealgrn_r",
)

fig.update_layout (
  height=500,
)

# %%
x = df[df['ticker'] == asset_name][['data_timestamp', 'cumulative_return', 'ticker']].sort_values(by="data_timestamp")

fig = px.line (
  x,
  "data_timestamp",
  "cumulative_return",
#   color_discrete_sequence="Tealgrn_r",
)

fig.update_layout (
  height=500,
)

# %%
x = df[df['ticker'] == asset_name][['data_timestamp', 'dca_bias', 'ticker']].sort_values(by="data_timestamp")

fig = px.line (
  x,
  "data_timestamp",
  "dca_bias",
#   color_discrete_sequence="Tealgrn_r",
)

fig.update_layout (
  height=500,
)

# %%
x = df[df['ticker'] == asset_name][['data_timestamp', 'cashflow', 'ticker']].sort_values(by="data_timestamp")

fig = px.line (
  x,
  "data_timestamp",
  "cashflow",
#   color_discrete_sequence="Tealgrn_r",
)

fig.update_layout (
  height=500,
)

# %%
x = df[df['ticker'] == asset_name][['data_timestamp', 'volatility_20d', 'volatility_30d', 'volatility_50d', 'ticker']].sort_values(by="data_timestamp")

fig = px.line (
  x,
  "data_timestamp",
  ['volatility_20d',"volatility_30d", "volatility_50d"],
#   color_discrete_sequence="Tealgrn_r",
)

fig.update_layout (
  height=500,
)

# %%
x = df[df['ticker'] == asset_name][['data_timestamp', 'ma_20d', 'ma_30d', 'ma_50d', 'ticker']].sort_values(by="data_timestamp")

fig = px.line (
  x,
  "data_timestamp",
  ['ma_20d',"ma_30d", "ma_50d"],
#   color_discrete_sequence="Tealgrn_r",
)

fig.update_layout (
  height=500,
)
