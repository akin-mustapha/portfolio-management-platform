# %%
import sys
from pathlib import Path

# Adjust depth to point at the repo root (parent of `src/`)
PROJECT_ROOT = Path.cwd().parents[1]  # from sandbox/notebooks/ → repo root
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

# %%
Path.cwd()
# Out:
# PosixPath('/Users/kunmi/workspace/projects/engineering/projects/portfolio-management-platform/sandbox/notebooks')

# %%
from src.shared.database.client import SQLModelClient

# %%
database_client = SQLModelClient(database_url="postgresql://dev_user_1:dev_user_1_password@localhost:5432/investment_db")

with database_client as db:
  res = db.execute(
    """
    select * from raw.t212_history_order limit 10;
"""
  )

  res = res.fetchall()

# %%
import pandas as pd


df = pd.DataFrame(res)
df.head()
# Out:
#             id ingested_date               ingested_timestamp  \
# 0  49863257365    2026-04-21 2026-04-20 23:35:31.694336+00:00
# 1  49701114401    2026-04-21 2026-04-20 23:35:31.695689+00:00
# 2  49701114437    2026-04-21 2026-04-20 23:35:31.696534+00:00
# 3  49701114438    2026-04-21 2026-04-20 23:35:31.697543+00:00
# 4  49701114442    2026-04-21 2026-04-20 23:35:31.698417+00:00
#
#                                              payload processed_at
# 0  {'fill': {'id': 49863257387, 'type': 'TRADE', ...         None
# 1  {'fill': {'id': 49856726809, 'type': 'TRADE', ...         None
# 2  {'fill': {'id': 49851462061, 'type': 'TRADE', ...         None
# 3  {'fill': {'id': 49851461405, 'type': 'TRADE', ...         None
# 4  {'fill': {'id': 49851461090, 'type': 'TRADE', ...         None

# %%
res[0][3]
# Out:
# {'fill': {'id': 49863257387,
#   'type': 'TRADE',
#   'price': 56.33,
#   'filledAt': '2026-04-20T14:52:45.000Z',
#   'quantity': 0.46287717,
#   'walletImpact': {'taxes': [{'name': 'CURRENCY_CONVERSION_FEE',
#      'currency': 'EUR',
#      'quantity': -0.05,
#      'chargedAt': '2026-04-20T14:52:45.697Z'}],
#    'fxRate': 0.87057999,
#    'currency': 'EUR',
#    'netValue': 30.0},
#   'tradingMethod': 'OTC'},
#  'order': {'id': 49863257365,
#   'side': 'BUY',
#   'type': 'MARKET',
#   'value': 30.0,
#   'status': 'FILLED',
#   'ticker': 'VUKGl_EQ',
#   'currency': 'EUR',
#   'strategy': 'VALUE',
#   'createdAt': '2026-04-20T14:52:42.000Z',
#   'instrument': {'isin': 'IE00BFMXYP42',
#    'name': 'Vanguard FTSE 100 (Acc)',
#    'ticker': 'VUKGl_EQ',
#    'currency': 'GBP'},
#   'filledValue': 30.0,
#   'extendedHours': False,
#   'initiatedFrom': 'IOS'}}

# %%
{"id": 49863257387, "type": "TRADE", "price": 56.33, "filledAt": "2026-04-20T14:52:45.000Z", "quantity": 0.46287717, "walletImpact": {
  "taxes": [
    {"name": "CURRENCY_CONVERSION_FEE",
     "currency": "EUR",
     "quantity": -0.05, 
     "chargedAt": "2026-04-20T14:52:45.697Z"
    }
  ],
    "fxRate": 0.87057999,
    "currency": "EUR",
    "netValue": 30.0
  }, "tradingMethod": "OTC"}

# %% [raw]
# {"id": 49701114438, "side": "BUY", "type": "MARKET", "value": 3.14, "status": "FILLED", "ticker": "VAGSl_EQ", "currency": "EUR", "strategy": "VALUE", "createdAt": "2026-04-20T07:05:50.000Z",
#     "instrument": {"isin": "IE00BG47K971", "name": "Vanguard Global Aggregate Bond (Acc)", "ticker": "VAGSl_EQ", "currency": "GBP"}, "filledValue": 3.14, "extendedHours": false, "initiatedFrom": "AUTOINVEST"}

# %%
{"isin": "IE00BFMXYP42", "name": "Vanguard FTSE 100 (Acc)", "ticker": "VUKGl_EQ", "currency": "GBP"}
